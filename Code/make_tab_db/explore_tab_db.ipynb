# %%
import pandas as pd

# Data\AGG_DB\5_hpo_reprise.csv
df = pd.read_csv("../../Data/AGG_DB/5_hpo_reprise.csv")
df.head()
# Out:
#     NO2_scd_min  NO2_scd_mean  NO2_scd_median   NO2_scd_max   NO2_scd_std  \
# 0  5.416535e+15  8.239230e+15    8.278994e+15  9.619553e+15  5.987017e+14
# 1  7.907679e+15  9.158703e+15    9.172164e+15  1.037429e+16  4.769905e+14
# 2  5.861161e+15  8.715355e+15    8.688822e+15  1.141075e+16  9.656280e+14
# 3  7.620466e+15  9.077866e+15    9.089090e+15  1.042800e+16  5.482104e+14
# 4  7.142379e+15  8.611275e+15    8.599386e+15  1.004870e+16  5.398255e+14
#
#     SO2_scd_min  SO2_scd_mean  SO2_scd_median   SO2_scd_max   SO2_scd_std  \
# 0 -3.950124e+16 -7.150764e+14    3.829303e+14  5.119998e+16  1.532467e+16
# 1 -3.190546e+16  1.754638e+15    1.977444e+15  3.392366e+16  1.428798e+16
# 2 -4.291300e+16  1.414651e+15    2.019564e+15  5.833183e+16  1.925703e+16
# 3 -2.580536e+16  6.583987e+15    5.612880e+15  7.133809e+16  1.563411e+16
# 4 -3.158334e+16 -6.676925e+14   -2.084389e+15  3.409705e+16  1.465171e+16
#
#    ...        date  ship_y         Proxy  n_ships  wind_mer_mean  \
# ...

# %%
print(df['ship_y'].value_counts())
# Out:
# ship_y
# 1    13858
# 0    11374
# Name: count, dtype: int64

# %%
df[df['ship_y'] == 1].hist(column='Proxy', bins=100, log=True)
# Out:
# array([[<Axes: title={'center': 'Proxy'}>]], dtype=object)

# %%
# print number of uniqe values in each column
print(df.nunique())
# Out:
# NO2_scd_min             24560
# NO2_scd_mean            25232
# NO2_scd_median          25227
# NO2_scd_max             24811
# NO2_scd_std             25232
# SO2_scd_min             24697
# SO2_scd_mean            25232
# SO2_scd_median          25229
# SO2_scd_max             24654
# SO2_scd_std             25232
# HCHO_scd_min            24737
# HCHO_scd_mean           25232
# HCHO_scd_median         25227
# HCHO_scd_max            24604
# HCHO_scd_std            25232
# date                      740
# ship_y                      2
# Proxy                   13363
# n_ships                    27
# wind_mer_mean           25232
# wind_zon_mean           25232
# sensor_zenith_angle     25232
# sensor_azimuth_angle    25232
# solar_azimuth_angle     25232
# solar_zenith_angle      25232
# dtype: int64
